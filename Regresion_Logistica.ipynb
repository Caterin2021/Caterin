# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
length = 4 

df = pd.read_csv('D:\Wales_covid.csv', index_col=False, header=0)

# %%
df
# Out:
#             date area_type area_name  daily_cases  cum_cases  \
# 0     2023-09-14    nation     Wales          NaN        NaN
# 1     2023-09-13    nation     Wales          2.0   904513.0
# 2     2023-09-12    nation     Wales         40.0   904511.0
# 3     2023-09-11    nation     Wales         38.0   904471.0
# 4     2023-09-10    nation     Wales         34.0   904433.0
# ...          ...       ...       ...          ...        ...
# 1291  2020-03-02    nation     Wales          0.0        1.0
# 1292  2020-03-01    nation     Wales          0.0        1.0
# 1293  2020-02-29    nation     Wales          0.0        1.0
# 1294  2020-02-28    nation     Wales          0.0        1.0
# 1295  2020-02-27    nation     Wales          1.0        1.0
#
#       new_deaths_28days  cum_deaths_28days  new_deaths_60days  \
# 0                   NaN                NaN                NaN
# 1                   0.0             8544.0                NaN
# ...

# %%
datos.isnull().sum()
# Out:
# date                    0
# area_type               0
# area_name               0
# daily_cases             1
# cum_cases               1
# new_deaths_28days      19
# cum_deaths_28days      19
# new_deaths_60days    1296
# cum_deaths_60days    1296
# new_first_episode       0
# cum_first_episode       1
# new_reinfections       79
# cum_reinfections       80
# new_virus_test         22
# cum_virus_test       1296
# new_pcr_test           22
# cum_pcr_test         1296
# new_lfd_test          429
# cum_lfd_test          429
# test_roll_pos_pct    1296
# test_roll_people     1296
# new_first_dose        537
# cum_first_dose        459
# new_second_dose       537
# cum_second_dose       480
# new_third_dose       1296
# cum_third_dose       1296
# new_admissions         98
# cum_admissions         98
# hospital_cases         98
# ventilator_beds        98
# trans_rate_min       1192
# trans_rate_max       1192
# trans_growth_min     1232
# trans_growth_max     1232
# dtype: int64

# %%
df[['new_deaths_60days','trans_rate_min','trans_rate_max']].head()
# Out:
#    new_deaths_60days  trans_rate_min  trans_rate_max
# 0                NaN             NaN             NaN
# 1                NaN             NaN             NaN
# 2                NaN             NaN             NaN
# 3                NaN             NaN             NaN
# 4                NaN             NaN             NaN

# %%
df[['cum_deaths_28days','cum_first_episode']].plot.scatter(x = 'cum_deaths_28days', y = 'cum_first_episode')
# Out:
# <Axes: xlabel='cum_deaths_28days', ylabel='cum_first_episode'>

# %%
w = 0.09
b = -3.6

# %%
x = np.linspace(0,df['cum_first_episode'].max(),100)
y = 1/(1+np.exp(-(w*x+b)))

# grafica de la recta
df.plot.scatter(x='cum_first_episode',y='cum_deaths_28days')
#plt.plot(x, y, '-r')
plt.plot(x, y, color = 'black')
plt.ylim(0,df['cum_deaths_28days'].max()*1.1)
plt.scatter(x, y, color='#A9E2F3')
# plt.grid()
plt.xlabel('episodiios')
plt.ylabel('muertes')
plt.show()
