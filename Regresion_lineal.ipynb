# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from sklearn import linear_model

import seaborn as sns

# %%
length = 4 

df = pd.read_csv('D:\Wales_covid.csv', index_col=False, header=0)

# %%
#Revisar Variable
df
# Out:
#             date area_type area_name  daily_cases  cum_cases  \
# 0     2023-09-14    nation     Wales          NaN        NaN
# 1     2023-09-13    nation     Wales          2.0   904513.0
# 2     2023-09-12    nation     Wales         40.0   904511.0
# 3     2023-09-11    nation     Wales         38.0   904471.0
# 4     2023-09-10    nation     Wales         34.0   904433.0
# ...          ...       ...       ...          ...        ...
# 1291  2020-03-02    nation     Wales          0.0        1.0
# 1292  2020-03-01    nation     Wales          0.0        1.0
# 1293  2020-02-29    nation     Wales          0.0        1.0
# 1294  2020-02-28    nation     Wales          0.0        1.0
# 1295  2020-02-27    nation     Wales          1.0        1.0
#
#       new_deaths_28days  cum_deaths_28days  new_deaths_60days  \
# 0                   NaN                NaN                NaN
# 1                   0.0             8544.0                NaN
# ...

# %%
#Grafica de dispersión
df.plot.scatter(x= "cum_cases", y= "cum_first_episode")
plt.show()

# %%
regresion = linear_model.LinearRegression()

# %%
cum_first_episode = df["cum_first_episode"].values.reshape((-1,1))

# %%
modelo = regresion.fit(cum_first_episode, df["cum_cases"])

print("Intersección (b)", modelo.intercept_)

print("Pendiente (m)", modelo.coef_)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 modelo = regresion.fit(cum_first_episode, df["cum_cases"])
#       3 print("Intersección (b)", modelo.intercept_)
#       5 print("Pendiente (m)", modelo.coef_)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:678, in LinearRegression.fit(self, X, y, sample_weight)
#     674 n_jobs_ = self.n_jobs
# ...

# %%
entrada = [[18],[22],[27]]
prediccion = modelo.predict(entrada)
print(prediccion)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 2
#       1 entrada = [[18],[22],[27]]
# ----> 2 prediccion = modelo.predict(entrada)
#       3 print(prediccion)
#
# NameError: name 'modelo' is not defined

# %%
datos.plot.scatter(x = "metro", y = "precio", label='Datos')
plt.scatter(entrada, prediccion, color='red')
plt.plot(entrada, prediccion, color='black', label='Regresión lineal')
plt.xlabel('Metros')
plt.ylabel('Precios')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 datos.plot.scatter(x = "metro", y = "precio", label='Datos')
#       2 plt.scatter(entrada, prediccion, color='red')
#       3 plt.plot(entrada, prediccion, color='black', label='Regresión lineal')
#
# NameError: name 'datos' is not defined
